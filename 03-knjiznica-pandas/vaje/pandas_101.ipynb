# %% [markdown]
# # Analiza podatkov s pandas
#
# [Pandas quick-start guide](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# [Pandas documentation](http://pandas.pydata.org/pandas-docs/stable/)
# [Lecture notes on pandas](../predavanja/Analiza podatkov s knjižnico Pandas.ipynb)

# %% [markdown]
# ### Naložimo pandas in podatke

# %%
# naložimo paket
import pandas as pd
import numpy as np

import os.path


# ker bomo delali z velikimi razpredelnicami, povemo, da naj se vedno izpiše le 10 vrstic
pd.options.display.max_rows = 10

# izberemo interaktivni "notebook" stil risanja
# %matplotlib notebook

# %%
# naložimo razpredelnico, s katero bomo delali
pot = os.path.join(
    '../../', '02-zajem-podatkov', 
    'predavanja', 'obdelani-podatki', 'filmi.csv'
)

filmi = pd.read_csv(pot, index_col='id')

# %% [markdown]
# Poglejmo si podatke.

# %%
filmi
# Out:
#                                                     naslov  dolzina  leto  \
# id
# 4972                                 The Birth of a Nation      195  1915
# 6864      Intolerance: Love's Struggle Throughout the Ages      163  1916
# 9968        Broken Blossoms or The Yellow Man and the Girl       90  1919
# 10323                         Das Cabinet des Dr. Caligari       76  1920
# 12349                                              The Kid       68  1921
# ...                                                    ...      ...   ...
# 11390036                                 A Fall from Grace      115  2020
# 11905962                                           Sputnik      113  2020
# 12393526                                           Bulbbul       94  2020
# 12567088                                    Raat Akeli Hai      149  2020
# 12749596                                              Host       57  2020
#
#           ocena  metascore  glasovi    zasluzek oznaka  \
# id
# 4972        6.3        NaN    22363  10000000.0    NaN
# 6864        7.7       99.0    13970   2180000.0    NaN
# 9968        7.3        NaN     9296         NaN    NaN
# 10323       8.1        NaN    56089         NaN    NaN
# 12349       8.3        NaN   110278   5450000.0    NaN
# ...         ...        ...      ...         ...    ...
# 11390036    5.8       34.0    10414         NaN    NaN
# 11905962    6.3       61.0     8285         NaN    NaN
# 12393526    6.6        NaN     8381         NaN    NaN
# 12567088    7.3        NaN    12232         NaN    NaN
# 12749596    6.6       72.0     8713         NaN    NaN
#
#                                                        opis
# id
# 4972      The Stoneman family finds its friendship with ...
# 6864      The story of a poor young woman, separated by ...
# 9968      A frail waif, abused by her brutal boxer fathe...
# 10323     Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 12349     The Tramp cares for an abandoned child, but ev...
# ...                                                     ...
# 11390036  Disheartened since her ex-husband's affair, Gr...
# 11905962  The lone survivor of an enigmatic spaceship in...
# 12393526  A man returns home after years to find his bro...
# 12567088  The film follows a small town cop who is summo...
# 12749596  Six friends hire a medium to hold a seance via...
#
# [10000 rows x 9 columns]

# %% [markdown]
# ## Proučevanje podatkov
#
# Razvrstite podatke po ocenah.

# %%
filmi.sort_values('ocena', ascending=False)
# Out:
#                                  naslov  dolzina  leto  ocena  metascore  \
# id
# 252487                   Hababam Sinifi       87  1975    9.3        NaN
# 111161             Kaznilnica odrešitve      142  1994    9.3       80.0
# 68646                             Boter      175  1972    9.2      100.0
# 5354160                        Aynabaji      147  2016    9.1        NaN
# 7738784                         Peranbu      147  2018    9.0        NaN
# ...                                 ...      ...   ...    ...        ...
# 5988370                            Reis      108  2017    1.4        NaN
# 6038600                        Smolensk      120  2016    1.4        NaN
# 4009460                Saving Christmas       79  2014    1.4       18.0
# 7886848                         Sadak 2      133  2020    1.1        NaN
# 7221896  Cumali Ceber: Allah Seni Alsin      100  2017    1.0        NaN
#
#          glasovi     zasluzek oznaka  \
# id
# 252487     36468          NaN    NaN
# 111161   2293163   28341469.0      R
# 68646    1582906  134966411.0    NaN
# 5354160    21429          NaN    NaN
# 7738784    11866          NaN    NaN
# ...          ...          ...    ...
# 5988370    72207          NaN    NaN
# 6038600     7630          NaN    NaN
# 4009460    14855    2783970.0     PG
# 7886848    57957          NaN    NaN
# 7221896    37659          NaN    NaN
#
#                                                       opis
# id
# 252487   Lazy, uneducated students share a very close b...
# 111161   Two imprisoned men bond over a number of years...
# 68646    The aging patriarch of an organized crime dyna...
# 5354160  Ayna is an actor and the prison is his stage. ...
# 7738784  A single father tries to raise his daughter, w...
# ...                                                    ...
# 5988370  A drama about the early life of Recep Tayyip E...
# 6038600  Inspired by true events of 2010 Polish Air For...
# 4009460  His annual Christmas party faltering thanks to...
# 7886848  The film picks up where Sadak left off, revolv...
# 7221896  Cumali Ceber goes to a vacation with his child...
#
# [10000 rows x 9 columns]

# %% [markdown]
# Poberite stolpec ocen.

# %%
filmi['ocena']
# Out:
# id
# 4972        6.3
# 6864        7.7
# 9968        7.3
# 10323       8.1
# 12349       8.3
#            ...
# 11390036    5.8
# 11905962    6.3
# 12393526    6.6
# 12567088    7.3
# 12749596    6.6
# Name: ocena, Length: 10000, dtype: float64

# %%
filmi[['naslov', 'ocena']]
# Out:
#                                                     naslov  ocena
# id
# 4972                                 The Birth of a Nation    6.3
# 6864      Intolerance: Love's Struggle Throughout the Ages    7.7
# 9968        Broken Blossoms or The Yellow Man and the Girl    7.3
# 10323                         Das Cabinet des Dr. Caligari    8.1
# 12349                                              The Kid    8.3
# ...                                                    ...    ...
# 11390036                                 A Fall from Grace    5.8
# 11905962                                           Sputnik    6.3
# 12393526                                           Bulbbul    6.6
# 12567088                                    Raat Akeli Hai    7.3
# 12749596                                              Host    6.6
#
# [10000 rows x 2 columns]

# %% [markdown]
# Ukaza `filmi['ocena']` in `filmi[['ocena']]` sta različna:

# %%
print(type(filmi['ocena']))
print(type(filmi[['ocena']]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Stolpci objekta `DataFrame` so tipa `Series`. Z enojnimi oklepaji poberemo `Series`, z dvojnimi oklepaji pa `DataFrame` podtabelo. Večina operacij (grouping, joining, plotting,  filtering, ...) deluje na `DataFrame`.
#
# Tip `Series` se uporablja ko želimo npr. dodati stolpec.

# %% [markdown]
# Zaokrožite stolpec ocen z funkcijo `round()`.

# %%
ocene_zaokrozene = round(filmi['ocena'])
ocene_zaokrozene
# Out:
# id
# 4972        6.0
# 6864        8.0
# 9968        7.0
# 10323       8.0
# 12349       8.0
#            ...
# 11390036    6.0
# 11905962    6.0
# 12393526    7.0
# 12567088    7.0
# 12749596    7.0
# Name: ocena, Length: 10000, dtype: float64

# %% [markdown]
# Dodajte zaokrožene vrednosti v podatke.

# %%
filmi['ocena_lepse'] = ocene_zaokrozene
filmi
# Out:
#                                                     naslov  dolzina  leto  \
# id
# 4972                                 The Birth of a Nation      195  1915
# 6864      Intolerance: Love's Struggle Throughout the Ages      163  1916
# 9968        Broken Blossoms or The Yellow Man and the Girl       90  1919
# 10323                         Das Cabinet des Dr. Caligari       76  1920
# 12349                                              The Kid       68  1921
# ...                                                    ...      ...   ...
# 11390036                                 A Fall from Grace      115  2020
# 11905962                                           Sputnik      113  2020
# 12393526                                           Bulbbul       94  2020
# 12567088                                    Raat Akeli Hai      149  2020
# 12749596                                              Host       57  2020
#
#           ocena  metascore  glasovi    zasluzek oznaka  \
# id
# 4972        6.3        NaN    22363  10000000.0    NaN
# 6864        7.7       99.0    13970   2180000.0    NaN
# 9968        7.3        NaN     9296         NaN    NaN
# 10323       8.1        NaN    56089         NaN    NaN
# 12349       8.3        NaN   110278   5450000.0    NaN
# ...         ...        ...      ...         ...    ...
# 11390036    5.8       34.0    10414         NaN    NaN
# 11905962    6.3       61.0     8285         NaN    NaN
# 12393526    6.6        NaN     8381         NaN    NaN
# 12567088    7.3        NaN    12232         NaN    NaN
# 12749596    6.6       72.0     8713         NaN    NaN
#
#                                                        opis  ocena_lepse
# id
# 4972      The Stoneman family finds its friendship with ...          6.0
# 6864      The story of a poor young woman, separated by ...          8.0
# 9968      A frail waif, abused by her brutal boxer fathe...          7.0
# 10323     Hypnotist Dr. Caligari uses a somnambulist, Ce...          8.0
# 12349     The Tramp cares for an abandoned child, but ev...          8.0
# ...                                                     ...          ...
# 11390036  Disheartened since her ex-husband's affair, Gr...          6.0
# 11905962  The lone survivor of an enigmatic spaceship in...          6.0
# 12393526  A man returns home after years to find his bro...          7.0
# 12567088  The film follows a small town cop who is summo...          7.0
# 12749596  Six friends hire a medium to hold a seance via...          7.0
#
# [10000 rows x 10 columns]

# %% [markdown]
# Odstranite novo dodani stolpec z metodo `.drop()` z podanim `columns = ` argumentom.

# %%
filmi = filmi.drop(columns = 'ocena')
filmi
# Out:
#                                                     naslov  dolzina  leto  \
# id
# 4972                                 The Birth of a Nation      195  1915
# 6864      Intolerance: Love's Struggle Throughout the Ages      163  1916
# 9968        Broken Blossoms or The Yellow Man and the Girl       90  1919
# 10323                         Das Cabinet des Dr. Caligari       76  1920
# 12349                                              The Kid       68  1921
# ...                                                    ...      ...   ...
# 11390036                                 A Fall from Grace      115  2020
# 11905962                                           Sputnik      113  2020
# 12393526                                           Bulbbul       94  2020
# 12567088                                    Raat Akeli Hai      149  2020
# 12749596                                              Host       57  2020
#
#           metascore  glasovi    zasluzek oznaka  \
# id
# 4972            NaN    22363  10000000.0    NaN
# 6864           99.0    13970   2180000.0    NaN
# 9968            NaN     9296         NaN    NaN
# 10323           NaN    56089         NaN    NaN
# 12349           NaN   110278   5450000.0    NaN
# ...             ...      ...         ...    ...
# 11390036       34.0    10414         NaN    NaN
# 11905962       61.0     8285         NaN    NaN
# 12393526        NaN     8381         NaN    NaN
# 12567088        NaN    12232         NaN    NaN
# 12749596       72.0     8713         NaN    NaN
#
#                                                        opis  ocena_lepse
# id
# 4972      The Stoneman family finds its friendship with ...          6.0
# 6864      The story of a poor young woman, separated by ...          8.0
# 9968      A frail waif, abused by her brutal boxer fathe...          7.0
# 10323     Hypnotist Dr. Caligari uses a somnambulist, Ce...          8.0
# 12349     The Tramp cares for an abandoned child, but ev...          8.0
# ...                                                     ...          ...
# 11390036  Disheartened since her ex-husband's affair, Gr...          6.0
# 11905962  The lone survivor of an enigmatic spaceship in...          6.0
# 12393526  A man returns home after years to find his bro...          7.0
# 12567088  The film follows a small town cop who is summo...          7.0
# 12749596  Six friends hire a medium to hold a seance via...          7.0
#
# [10000 rows x 9 columns]

# %% [markdown]
# ### Opomba: slice
# Izbira podtabele ustvari t.i. "rezino" oz. "slice".
# Slice ni kopija tabele, temveč zgolj sklic na izvorno tabelo,
# in je zato ne moremo spreminjati.
# Če želimo kopijo, uporabimo metodo `.copy()` na rezini, ki jo nato lahko spreminjamo.

# %% [markdown]
# Izberite podtabelo s stolpci `naslov`, `leto`, in `glasovi`, kateri nato dodate solpec z zaokroženimi ocenami.

# %%
zanimivo = (filmi[['naslov', 'leto', 'glasovi', 'ocena_lepse']]).copy()
zanimivo['ocena_lepse'] = zanimivo['ocena_lepse'].astype(int)
zanimivo
# Out:
#                                                     naslov  leto  glasovi  \
# id
# 4972                                 The Birth of a Nation  1915    22363
# 6864      Intolerance: Love's Struggle Throughout the Ages  1916    13970
# 9968        Broken Blossoms or The Yellow Man and the Girl  1919     9296
# 10323                         Das Cabinet des Dr. Caligari  1920    56089
# 12349                                              The Kid  1921   110278
# ...                                                    ...   ...      ...
# 11390036                                 A Fall from Grace  2020    10414
# 11905962                                           Sputnik  2020     8285
# 12393526                                           Bulbbul  2020     8381
# 12567088                                    Raat Akeli Hai  2020    12232
# 12749596                                              Host  2020     8713
#
#           ocena_lepse
# id
# 4972                6
# 6864                8
# 9968                7
# 10323               8
# 12349               8
# ...               ...
# 11390036            6
# 11905962            6
# 12393526            7
# 12567088            7
# 12749596            7
#
# [10000 rows x 4 columns]

# %% [markdown]
# ### Filtracija
#
# Ustvarite filter, ki izbere filme, ki so izšli pred 1930, in filter za filme po 2017.
# Združite ju za izbor filmov, ki so izšli pred 1930 ali po 2017.

# %%
prej = filmi['leto'] < 1930
potem = filmi['leto'] > 2017
izbrani = filmi[prej | potem]
izbrani
# Out:
#                                                     naslov  dolzina  leto  \
# id
# 4972                                 The Birth of a Nation      195  1915
# 6864      Intolerance: Love's Struggle Throughout the Ages      163  1916
# 9968        Broken Blossoms or The Yellow Man and the Girl       90  1919
# 10323                         Das Cabinet des Dr. Caligari       76  1920
# 12349                                              The Kid       68  1921
# ...                                                    ...      ...   ...
# 11390036                                 A Fall from Grace      115  2020
# 11905962                                           Sputnik      113  2020
# 12393526                                           Bulbbul       94  2020
# 12567088                                    Raat Akeli Hai      149  2020
# 12749596                                              Host       57  2020
#
#           metascore  glasovi    zasluzek oznaka  \
# id
# 4972            NaN    22363  10000000.0    NaN
# 6864           99.0    13970   2180000.0    NaN
# 9968            NaN     9296         NaN    NaN
# 10323           NaN    56089         NaN    NaN
# 12349           NaN   110278   5450000.0    NaN
# ...             ...      ...         ...    ...
# 11390036       34.0    10414         NaN    NaN
# 11905962       61.0     8285         NaN    NaN
# 12393526        NaN     8381         NaN    NaN
# 12567088        NaN    12232         NaN    NaN
# 12749596       72.0     8713         NaN    NaN
#
#                                                        opis  ocena_lepse
# id
# 4972      The Stoneman family finds its friendship with ...          6.0
# 6864      The story of a poor young woman, separated by ...          8.0
# 9968      A frail waif, abused by her brutal boxer fathe...          7.0
# 10323     Hypnotist Dr. Caligari uses a somnambulist, Ce...          8.0
# 12349     The Tramp cares for an abandoned child, but ev...          8.0
# ...                                                     ...          ...
# 11390036  Disheartened since her ex-husband's affair, Gr...          6.0
# 11905962  The lone survivor of an enigmatic spaceship in...          6.0
# 12393526  A man returns home after years to find his bro...          7.0
# 12567088  The film follows a small town cop who is summo...          7.0
# 12749596  Six friends hire a medium to hold a seance via...          7.0
#
# [749 rows x 9 columns]

# %% [markdown]
# Definirajte funkcijo, ki preveri ali niz vsebuje kvečjemu dve besedi. Nato s pomočjo `.apply()` izberite vse filme z imeni daljšimi od dveh besed in oceno nad 8.

# %%
dobra_ocena = filmi['ocena_lepse'] > 8

def daljsi_od_dveh_besed(naslov):
    return len(naslov.split()) > 2

dolga_imena = filmi['naslov'].apply(daljsi_od_dveh_besed)

dobri_filmi = filmi[dobra_ocena & dolga_imena]
dobri_filmi
# Out:
#                                                     naslov  dolzina  leto  \
# id
# 50083                                        12 jeznih mož       96  1957
# 59550       Operatsiya 'Y' i drugie priklyucheniya Shurika       95  1965
# 60196                                  Dober, grd, hudoben      161  1966
# 71562                                       Boter, II. del      202  1974
# 73486                           Let nad kukavičjim gnezdom      133  1975
# ...                                                    ...      ...   ...
# 253614                                    Saban Oglu Saban       90  1977
# 263975                            Selvi Boylum Al Yazmalim       90  1977
# 271383                               O Auto da Compadecida      104  2000
# 317248                                      Cidade de Deus      130  2002
# 2077886  The Phantom of the Opera at the Royal Albert Hall      137  2011
#
#          metascore  glasovi     zasluzek oznaka  \
# id
# 50083         96.0   673688    4360000.0    NaN
# 59550          NaN    11693          NaN    NaN
# 60196         90.0   676502    6100000.0    NaN
# 71562         90.0  1105879   57300000.0    NaN
# 73486         83.0   899748  112000000.0    NaN
# ...            ...      ...          ...    ...
# 253614         NaN    15852          NaN    NaN
# 263975         NaN    14502          NaN    NaN
# 271383         NaN    11452          NaN    NaN
# 317248        79.0   689090    7563397.0      R
# 2077886        NaN     7920          NaN    NaN
#
#                                                       opis  ocena_lepse
# id
# 50083    A jury holdout attempts to prevent a miscarria...          9.0
# 59550    Three stories about Shurik - a young student. ...          9.0
# 60196    A bounty hunting scam joins two men in an unea...          9.0
# 71562    The early life and career of Vito Corleone in ...          9.0
# 73486    A criminal pleads insanity and is admitted to ...          9.0
# ...                                                    ...          ...
# 253614   Husamettin the commander in the army is consta...          9.0
# 263975   Story of a dilemma between a woman's love and ...          9.0
# 271383   João Grilo and Chicó are two very poor and cle...          9.0
# 317248   In the slums of Rio, two kids' paths diverge a...          9.0
# 2077886  A disfigured musical genius, hidden away in th...          9.0
#
# [25 rows x 9 columns]

# %% [markdown]
# ### Histogrami
#
# Združite filme po ocenah in jih preštejte.

# %%
filmi.groupby('ocena_lepse').size()
# Out:
# ocena_lepse
# 1.0       5
# 2.0      40
# 3.0      56
# 4.0     221
# 5.0     829
# 6.0    3220
# 7.0    3534
# 8.0    2029
# 9.0      66
# dtype: int64

# %% [markdown]
# Naredite stolpični diagram teh podatkov.

# %%
filmi.groupby('ocena_lepse').size().plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='ocena_lepse'>

# %% [markdown]
# Tabele imajo metodo `.hist()`, ki omogoča izgradnjo histogramov za stolpce. Uporabite to metodo za prikaz poenostavljenih podatkov.

# %%
filmi.groupby('ocena_lepse').hist()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ocena_lepse
# 1.0    [[AxesSubplot(0.125,0.666111;0.336957x0.213889...
# 2.0    [[AxesSubplot(0.125,0.666111;0.336957x0.213889...
# 3.0    [[AxesSubplot(0.125,0.666111;0.336957x0.213889...
# 4.0    [[AxesSubplot(0.125,0.666111;0.336957x0.213889...
# 5.0    [[AxesSubplot(0.125,0.666111;0.336957x0.213889...
# 6.0    [[AxesSubplot(0.125,0.666111;0.336957x0.213889...
# 7.0    [[AxesSubplot(0.125,0.666111;0.336957x0.213889...
# 8.0    [[AxesSubplot(0.125,0.666111;0.336957x0.213889...
# 9.0    [[AxesSubplot(0.125,0.666111;0.336957x0.213889...
# dtype: object

# %% [markdown]
# ### Izris povprečne dolžine filma glede na leto

# %%
filmi.groupby('leto').mean()[['dolzina']].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='leto'>

# %% [markdown]
# ### Izris skupnega zasluzka za posamezno leto

# %%
filmi.groupby('leto').sum()[['zasluzek']].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='leto'>
